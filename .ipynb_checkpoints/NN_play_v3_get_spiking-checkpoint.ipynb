# %%
import mnist_loader
import network
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
import cPickle as pickle

# %%
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 16}

matplotlib.rc('font', **font)

# %%
reload(mnist_loader)
training_data, validation_data, test_data,train_ae,val_ae,test_ae = mnist_loader.load_data_wrapper(make_binary =True)
# Out:
# (<type 'list'>, (50000, 784, 1))
# (<type 'list'>, (50000, 10, 1))

# %%
net = network.Network([784, 30, 10], cost=network.CrossEntropyCost,doSmallWorld=False)
net.large_weight_initializer()
net.SGD(training_data, 10, 10, 0.5,evaluation_data = validation_data)
test_out = [x[1] for x in test_data]
# Out:
# Epoch 0 training complete
#
# Epoch 1 training complete
#
# Epoch 2 training complete
#
# Epoch 3 training complete
#
# Epoch 4 training complete
#
# Epoch 5 training complete
#
# Epoch 6 training complete
#
# Epoch 7 training complete
#
# Epoch 8 training complete
#
# Epoch 9 training complete

# %%
dat = []
dat.append([net.weights,net.biases])
dat.append([net_ae.weights, net_ae.biases])
dat.append([net_ae.weights, net_ae.biases])
pickle.dump((dat,disc), open( "blah.p", "wb" ))

# %%
disc = []
disc += ['OG']
this_lay = 5
disc += ['Bottle:' + str(this_lay)]
disc += ['Tim']
disc
# Out:
# ['OG', 'Bottle:5', 'Tim']

# %% [markdown]
# # Try autoendoder Network

# %%
reload(network)
net_ae = network.Network([784,30,10,30,784], cost=network.QuadraticCost,doHeavy = False,doSmallWorld=False,add_rand=10)
net_ae.large_weight_initializer()
net_ae.SGD(train_ae, 10, 10, 0.5,evaluation_data=val_ae) # 10, 10, 0.5
# Out:
# Epoch 0 training complete
#
# Epoch 1 training complete
#
# Epoch 2 training complete
#
# Epoch 3 training complete
#
# Epoch 4 training complete
#
# Epoch 5 training complete
#
# Epoch 6 training complete
#
# Epoch 7 training complete
#
# Epoch 8 training complete
#
# Epoch 9 training complete
# ([], [], [], [])

# %%
# 1) produce reconstructed images using net_ae
# 2) train classification network on output of ae network (training set)
# 3) get accuracy for both all four cases

# 1)
train_dat_in = np.transpose(np.squeeze([x[0] for x in training_data]))
val_dat_in = np.transpose(np.squeeze([x[0] for x in validation_data]))
test_dat_in = np.transpose(np.squeeze([x[0] for x in test_data]))

train_dat_remake = net_ae.feedforward(train_dat_in)
val_dat_remake = net_ae.feedforward(val_dat_in)
test_dat_remake = net_ae.feedforward(test_dat_in)

# %%
def make_train_input(X,OG):
    bar = np.transpose(X)
    foo_in = list()
    foo_out = list()
    for i in range(len(bar)):
        foo_in.append(bar[i][:,np.newaxis])
    foo_out = [i[1] for i in OG]
    return zip(foo_in,foo_out)
    
training_data_new = make_train_input(train_dat_remake,training_data)
val_data_new =  make_train_input(val_dat_remake,validation_data)
test_dat_new = make_train_input(test_dat_remake,test_data)

# %%
# 2
net2 = network.Network([784, 30, 10], cost=network.CrossEntropyCost,doSmallWorld=False)
net2.large_weight_initializer()
net2.SGD(training_data_new, 10, 10, 0.5,evaluation_data = val_data_new)
# Out:
# Epoch 0 training complete
#
# Epoch 1 training complete
#
# Epoch 2 training complete
#
# Epoch 3 training complete
#
# Epoch 4 training complete
#
# Epoch 5 training complete
#
# Epoch 6 training complete
#
# Epoch 7 training complete
#
# Epoch 8 training complete
#
# Epoch 9 training complete
# ([], [], [], [])

# %%
#3 acc_train_test
acc_og_ae,acc_og_og = float(net.accuracy(test_dat_new))/len(test_data),float(net.accuracy(test_data))/len(test_data)
acc_ae_ae,acc_ae_og = float(net2.accuracy(test_dat_new))/len(test_data),float(net2.accuracy(test_data))/len(test_data)

# %%
print('OG Network, OG data:',acc_og_og,'AE data',acc_og_ae)
print('AE Network, OG data:',acc_ae_og,'AE data',acc_ae_ae)
# Out:
# ('OG Network, OG data:', 0.9362, 'AE data', 0.7977)
# ('AE Network, OG data:', 0.7576, 'AE data', 0.8473)

# %%
# MSE of 5 layer NN
#test_dat_remake_b = test_dat_remake>=.5*1
MSE_pixel = np.mean((test_dat_in-test_dat_remake)**2,axis=1)
plt.imshow(np.reshape(MSE_pixel,(28,28)),cmap='gray')
plt.colorbar()
plt.title('MSE by Pixel')
plt.show()

plt.plot(x_ent,MSE_pixel,'k.',alpha=.5)
plt.xlabel('Pixel Entropy')
plt.ylabel('MSE Autoencoder')
plt.title('Pearsons rho: ' + str(round(corr(np.squeeze(x_ent),MSE_pixel),2)))
plt.show()

# %%
rel_var = np.mean(np.var(test_dat_in,1))
test_dat_remake[10][20]
print('Var in: ',rel_var,'MSE AE: ',np.mean(MSE_pixel))
#a,b = pearsonr(np.squeeze(x_ent),MSE_pixel)
# Out:
# ('Var in: ', 0.085504131109694431, 'MSE AE: ', 0.04907575040632773)
# 0.0

# %%
def use_decode(wts,bias,a):
    for b, w in zip(bias, wts):
        a = sigmoid(np.dot(w, a)+b)
    return a

def sigmoid(z):
    """The sigmoid function."""
    return 1.0/(1.0+np.exp(-z))

def heavyside_99(z):
    """Heavyside Function w/o hitting edge"""
    return (z>0)*.99+((z>0)==0)*.01

def encode_decode(wts,bias,in_val,get_act = False):
    try:
        n_bottleneck = len(wts[2][1]) # assuming 5 layer NN
        do_tran = False
    except:  
        n_bottleneck = len(wts[2]) # correction for data type
        do_tran = True 
    n_layer = len(wts)
    n_trials = len(in_val)
    n_dim = np.shape(test_ae)[2]
    bot_val = np.zeros((n_trials,n_bottleneck))
    img_out = np.zeros((n_trials,n_dim))
    
    sum_a = 0
    if do_tran:
        wts = [np.transpose(x) for x in wts]
        bias = [np.transpose(x) for x in bias]
    for i in range(len(in_val)):
        a = in_val[i][0]
        for ii in range(n_layer):
            a = sigmoid(np.dot(wts[ii],a)+bias[ii])
            sum_a += np.sum(a)
            if ii == 1:
                bot_val[i,:] = np.squeeze(a)
            if ii == n_layer-1:
                img_out[i,:] = np.squeeze(a)

    return bot_val, img_out, sum_a/len(in_val)

def bin_ent(p): 
    ent = -(p*np.log2(p)+(1-p)*np.log2(1-p))
    ent[np.isnan(ent)]=0
    return ent

# %%
def quick_eval(net_in,VERBOSE = False):
    wts = net_in.weights
    bias = net_in.biases

    decoder_wts = wts[2:]
    decoder_bias = bias[2:]
    encoder_wts = wts[0:2]
    encoder_bias = bias[0:2]

    bottle_val,img_out,sum_a = encode_decode(wts,bias,test_ae) #[:10000]
    
    bottle_val_bool = (bottle_val>.5)*1
    avg_val = np.mean(bottle_val_bool,0)
    print('Entropy:',np.sum(bin_ent(avg_val)),'Activity:',sum_a)

    # classify outputs using old network
    #img_out_b = (img_out>.5)*1
    img_out_bt = np.transpose((img_out>.5)*1)
    posteriors = net.feedforward(img_out_bt)
    pred = np.argmax(posteriors,0)
    acc = np.mean(pred==test_out)
    acc_og = net.accuracy(test_data)*1.0
    acc_og = acc_og/len(test_data)
    print('Acc Reconstructed:',acc,'Acc OG:',acc_og)

    if VERBOSE:
        # plot images
        in_dat  = test_ae[45][0] # 45
        cent = use_decode(encoder_wts,encoder_bias,in_dat)
        in_probe = cent
        tmp_out = use_decode(decoder_wts,decoder_bias,in_probe)
        tmp2 = tmp_out
        tmp2 = (tmp2>.5)*1

        plt.subplot(1,3,1)
        plt.imshow(np.reshape(in_dat,(28,28)),cmap='gray')
        plt.title('Original')
        plt.subplot(1,3,2)
        plt.stem(cent)
        plt.title('Low Dim Rep')
        plt.subplot(1,3,3)
        plt.imshow(np.reshape(tmp2,(28,28)),cmap='gray')
        plt.title('Reproduction')
        plt.show()

        # plot middle layer
        plt.subplot(1,2,1)
        plt.plot(bottle_val,'ko',alpha=.01)
        plt.subplot(1,2,2)
        f_val = bottle_val.flatten()
        plt.hist(f_val,100)
        plt.show()

# %%
def quick_eval_2(net_in):
    net = net2 # try R network
    try:
        wts = net_in.weights
        bias = net_in.biases
    except:
        wts = net_in[0]
        bias = net_in[1]

    decoder_wts = wts[2:]
    decoder_bias = bias[2:]
    encoder_wts = wts[0:2]
    encoder_bias = bias[0:2]

    bottle_val,img_out,sum_a = encode_decode(wts,bias,test_ae) #[:10000]
    
    bottle_val_bool = (bottle_val>.5)*1
    avg_val = np.mean(bottle_val_bool,0)
    entropy_bottle = np.sum(bin_ent(avg_val))
    total_activity = sum_a

    # classify outputs using old network
    img_out_bt = np.transpose((img_out>.5)*1)
    posteriors = net.feedforward(img_out_bt)
    pred = np.argmax(posteriors,0)
    acc = np.mean(pred==test_out)
    acc_og = net.accuracy(test_data)*1.0
    acc_og = acc_og/len(test_data)
    acc_original = acc_og
    acc_reconstruct = acc
    
    return entropy_bottle, total_activity, acc_original, acc_reconstruct

# %%
my_nets = [i for i in dat[0]]
nnets = len(my_nets)

ent = np.zeros(nnets)
act = np.zeros(nnets)
acc_rec = np.zeros(nnets)

for i in range(nnets):
    ent[i],act[i],acc_og,acc_rec[i] = quick_eval_2(my_nets[i])

# %%
#pct_sw = [0,1,5,10,15,20]
pct_sw = np.arange(-1,50,2)
vw = np.arange(1,len(pct_sw)-1)
act_use = act/sum([28*28,30,5,30,28*28])*100

plt.figure(figsize=(12,14))
plt.subplot(2,2,1)
plt.plot(pct_sw[1:],acc_rec[1:])
plt.plot([0, 50],[acc_og, acc_og],'r--')
plt.ylabel('Accuracy')
plt.xlabel('Percent Long Range Connections')

plt.subplot(2,2,2)
plt.plot(pct_sw[1:],act_use[1:])
plt.plot([0,50],[act_use[0],act_use[0]],'r--')
plt.ylabel('Overall Activity Levels (% max)')
plt.xlabel('Percent Long Range Connections')

plt.subplot(2,2,3)
vw = np.arange(1,len(pct_sw)-1)
plt.plot(pct_sw[1:],ent[1:])
plt.plot([0,50],[ent[0],ent[0]],'r--')
plt.ylabel('Entropy')
plt.xlabel('Percent Long Range Connections')

plt.subplot(2,2,4)
plt.plot(ent[1:],act_use[1:],'ko')
plt.title('Pearsons rho: ' + str(round(corr(ent[1:],act_use[1:]),2)))
plt.xlabel('Entropy')
plt.ylabel('Overall Activity')
plt.show()

# %%
def corr(x,y):
    assert np.ndim(x)==1 & np.ndim(y)==1
    # mean subtract
    x = x-np.mean(x)
    y = y-np.mean(y)
    # pearsons correlation
    cor = np.sum(x*y)/np.sqrt(np.sum(x**2)*np.sum(y**2))
    return cor
corr(ent[1:],act[1:])
pearsonr(ent[1:],act[1:])
.113/2
# Out:
# 0.0565

# %%
fn2 = 'bottle_weights_more.p'
dat2 = pickle.load(open(fn2))

my_nets2 = [i for i in dat2[0]]
nnets = len(my_nets2)

ent2 = np.zeros(nnets)
act2 = np.zeros(nnets)
acc_rec2 = np.zeros(nnets)

for i in range(nnets):
    ent2[i],act2[i],acc_og,acc_rec2[i] = quick_eval_2(my_nets2[i])
# Out:
# /home/AD/tsheehan/anaconda3/envs/mne/lib/python2.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: divide by zero encountered in log2

# %%
n_bot = np.concatenate([[x,x] for x in np.arange(1,50,2)])
n_bot = np.insert(n_bot,0,0,axis=0)
is_SW = np.array([x%2==0 for x in range(51)])
not_SW = is_SW==0
is_SW[0] =False

def n_tot(bot):
    return sum([28*28,30,bot,30,28*28])
n_lay = n_tot(n_bot)
act2c = (act2/n_lay)*100
acc_rec2
# Out:
# array([ 0.7604,  0.3804,  0.2876,  0.619 ,  0.5564,  0.7419,  0.6503,
#         0.7454,  0.6715,  0.7644,  0.7066,  0.81  ,  0.7554,  0.7895,
#         0.7621,  0.7991,  0.7458,  0.7754,  0.7879,  0.7994,  0.801 ,
#         0.8004,  0.7923,  0.8093,  0.8206,  0.8116,  0.8326,  0.8212,
#         0.8097,  0.8292,  0.8272,  0.822 ,  0.8347,  0.833 ,  0.8352,
#         0.8303,  0.7961,  0.7996,  0.8442,  0.8374,  0.8217,  0.8234,
#         0.8371,  0.8495,  0.8195,  0.8368,  0.8519,  0.831 ,  0.8331,
#         0.8303,  0.8485])

# %%
plt.figure(figsize=(12,14))
plt.subplot(2,2,1)
plt.plot(n_bot[is_SW],acc_rec2[is_SW],label='Small World Network')
plt.plot(n_bot[not_SW],acc_rec2[not_SW],label='Full Network')
plt.plot([0, 50],[acc_og, acc_og],'r--')
plt.ylabel('Accuracy')
plt.xlabel('Size Bottleneck Layer')
plt.legend()

plt.subplot(2,2,2)
plt.plot(n_bot[is_SW],act2c[is_SW],label='Small World Network')
plt.plot(n_bot[not_SW],act2c[not_SW],label='Full Network')
plt.ylabel('Overall Activity Levels (% max)')
plt.xlabel('Size Bottleneck Layer')

plt.subplot(2,2,3)
plt.plot(n_bot[is_SW],ent2[is_SW],label='Small World Network')
plt.plot(n_bot[not_SW],ent2[not_SW],label='Full Network')
plt.ylabel('Entropy')
plt.xlabel('Size Bottleneck Layer')

plt.subplot(2,2,4)
plt.plot(n_bot[is_SW],ent2[is_SW]/n_bot[is_SW],label='Small World Network')
plt.plot(n_bot[not_SW],ent2[not_SW]/n_bot[not_SW],label='Full Network')
plt.ylabel('Entropy (% Max)')
plt.xlabel('Size Bottleneck Layer')
plt.show()

# %%
plt.plot(ent2[is_SW],act2c[is_SW],'ko',label='Small World')
plt.plot(ent2[not_SW],act2c[not_SW],'mo', label='Full')
plt.xlabel('Entropy')
plt.ylabel('Network Activity')
plt.legend()
# plt.plot(ent2[is_SW]/n_bot[is_SW],act2c[is_SW],'ko')
# plt.plot(ent2[not_SW]/n_bot[not_SW],act2c[not_SW],'mo')
# plt.plot(act2c[is_SW],ent2[is_SW]/n_bot[is_SW],'ko')
# plt.plot(act2c[not_SW],ent2[not_SW]/n_bot[not_SW],'mo')
plt.show()

# %%
from scipy.stats import spearmanr
spearmanr(ent2[is_SW],act2c[is_SW])
spearmanr(ent2[not_SW],act2c[not_SW])
# Out:
# SpearmanrResult(correlation=0.74461538461538457, pvalue=1.9663309528031137e-05)

# %%
quick_eval(net_ae,True)
# Out:
# ('Entropy:', 9.6658814346959812, 'Activity:', 134.75192292732353)
# ('Acc Reconstructed:', 0.5988, 'Acc OG:', 0.8007)

# %%
quick_eval(net_ae_we0,True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-35fcfc3ea59c> in <module>()
# ----> 1 quick_eval(net_ae_we0,True)
#
# NameError: name 'net_ae_we0' is not defined

# %%
quick_eval(net_ae_we01,True)
# Out:
# /Users/sheehantc/miniconda3/envs/py2/lib/python2.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in exp
#
# /Users/sheehantc/miniconda3/envs/py2/lib/python2.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: divide by zero encountered in log2
# /Users/sheehantc/miniconda3/envs/py2/lib/python2.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in multiply
# ('Entropy:', 0.0, 'Activity:', 49.934523513459908)
# ('Acc Reconstructed:', 0.1028, 'Acc OG:', 8277)

# %%
quick_eval(net_ae_we10,True)
# Out:
# /Users/sheehantc/miniconda3/envs/py2/lib/python2.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: divide by zero encountered in log2
# /Users/sheehantc/miniconda3/envs/py2/lib/python2.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in multiply
# ('Entropy:', 0.44968221312250012, 'Activity:', 36.197241706468972)
# ('Acc Reconstructed:', 0.1028, 'Acc OG:', 8277)

# %%
quick_eval(net_ae_we0001,True)
# Out:
# /Users/sheehantc/miniconda3/envs/py2/lib/python2.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in exp
#
# /Users/sheehantc/miniconda3/envs/py2/lib/python2.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: divide by zero encountered in log2
# /Users/sheehantc/miniconda3/envs/py2/lib/python2.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in multiply
# ('Entropy:', 0.0, 'Activity:', 128.23522997720238)
# ('Acc Reconstructed:', 0.1028, 'Acc OG:', 8277)

# %%
# TO DO
# Add Noise
# measure stats in function
#  -acc
#  -entropy
# Add energy use penalty

# %% [markdown]
# # compute entropy

# %%
# now that it is binary simply compute 
foo = training_data
x = [i[0] for i in training_data]
x_avg = np.mean(x,0)
x_ent = bin_ent(x_avg)
plt.subplot(1,2,1)
plt.imshow(np.reshape(x_avg,(28,28)),vmin=0, vmax=1,cmap='gray')
plt.title('Avg Value')
plt.subplot(1,2,2)
plt.imshow(np.reshape(x_ent,(28,28)),vmin=0, vmax=1,cmap='gray')
plt.title('Entropy (Bits)')
plt.show()
# Out:
# /home/AD/tsheehan/anaconda3/envs/mne/lib/python2.7/site-packages/ipykernel_launcher.py:44: RuntimeWarning: divide by zero encountered in log2

# %%
plt.hist(x_ent,20,color='w',edgecolor="k")
plt.xlabel('Pixel Entropy')
plt.ylabel('# Pixels')
plt.show()
from scipy.stats import skew
print('Avg Entropy:',np.mean(x_ent))
print('Median Entropy:',np.median(x_ent))
print('Total Entropy:',np.sum(x_ent))
print('Skew:',skew(x_ent))
# Out:
# ('Avg Entropy:', 0.37742615682321057)
# ('Median Entropy:', 0.18251650887196114)
# ('Total Entropy:', 295.90210694939708)
# ('Skew:', array([ 0.48689002]))

# %%
np.sum(x_ent)/5
# Out:
# 59.180421389879413

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
plt.imshow(np.reshape(x_avg,(28,28)),vmin=0, vmax=1,cmap='gray')
plt.title('Avg Value')
plt.subplot(2,2,2)
plt.plot(x,bin_ent(x),'k--')
plt.xlabel('p(x)')
plt.ylabel('Entropy (Bits)')
plt.title('Shannon Entropy')
plt.subplot(2,2,3)
plt.imshow(np.reshape(x_ent,(28,28)),vmin=0, vmax=1,cmap='gray')
plt.title('Entropy (Bits)')
plt.subplot(2,2,4)
plt.hist(x_ent,20,color='w',edgecolor="k")
plt.xlabel('Pixel Entropy')
plt.ylabel('# Pixels')
plt.show()

# %%
x = np.arange(0.01,1,.01)
plt.plot(x,bin_ent(x))
plt.xlabel('p(x)')
plt.ylabel('Entropy (Bits)')x = np.arange(0.01,1,.01)
plt.show()

# %%
foo = list(map(lambda x:(x>.5)*1,t_in))

# %%
net_size = [28*28,30,5,30,28*28]
plt.title('Reconstructed Image')
import random
from scipy.spatial.distance import cdist 
#for n in range(len(net_size)-1):
n = 0

rad1 = (np.arange(net_size[n],dtype=float)/net_size[n])*2*np.pi
rad2 = (np.arange(net_size[n+1],dtype=float)/net_size[n+1])*2*np.pi

def xy_dist_rad(rad1,rad2):
 
    return mat
def gen_weights_local(nx,ny,tol,add_rand=None):
    rad1 = (np.arange(nx,dtype=float)/nx)*2*np.pi
    rad2 = (np.arange(ny,dtype=float)/ny)*2*np.pi
    loc1 = np.transpose(np.array([np.cos(rad1),np.sin(rad1)]))
    loc2 = np.transpose(np.array([np.cos(rad2),np.sin(rad2)]))
    mat = cdist(loc2,loc1)
    in_thresh = mat<tol
    norm = np.mean(in_thresh)*np.sqrt(nx)
    if add_rand:
        long_cnx = add_rand_con(nx,ny,add_rand)
        in_thresh[long_cnx] = 1
    wts = np.random.randn(ny, nx)/norm
    wts[in_thresh==0] = 0
    return wts
def add_rand_con(nx,ny,pct):
    #nx,ny,pct = 20,5,10
    pool = np.arange(nx*ny)
    cnx = np.array(random.sample(pool,nx*ny*pct/100))
    p_x = cnx%nx
    p_y = cnx//nx
    new_wts = np.zeros((ny,nx))==1
    new_wts[p_y,p_x] = True
    return new_wts

# %%
tol = .8
n = 3
wts = gen_weights_local(net_size[n],net_size[n+1],tol,add_rand = 10)

net_size = [28*28,30,5,30,28*28]

rad1 = (np.arange(net_size[n],dtype=float)/net_size[n])*2*np.pi
rad2 = (np.arange(net_size[n+1],dtype=float)/net_size[n+1])*2*np.pi
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.plot(np.cos(rad1),np.sin(rad1),'k.',markersize=10,label='Layer 3')
plt.plot(np.cos(rad2)*.97,np.sin(rad2)*.97,'m.-',markersize=1,label='Layer 4')
plt.xlabel('X-pos')
plt.ylabel('Y-pos')
plt.title('Node Latent Space')
plt.legend()
plt.subplot(1,2,2)
plt.pcolormesh(wts,cmap='PiYG',vmin=-.2,vmax=.2) # cmap='RdBu'
plt.xlabel('Layer 3')
plt.ylabel('Layer 4')
plt.title('Initialized Synaptic Weights')
plt.colorbar()
plt.show()

# %%
wts_localOnly = gen_weights_local(net_size[n],net_size[n+1],tol)
np.mean(wts_localOnly!=0)
# Out:
# 0.26198979591836735

# %%
np.shape(foo[1])
np.shape(foo[0][0])
# Out:
# (2, 4)

# %%
foo[1]
# Out:
# ['OG', 'Bottle:5', 'Tim']
